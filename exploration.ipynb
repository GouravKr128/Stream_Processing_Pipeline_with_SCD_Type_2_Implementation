# %%
spark.conf.set(
  "fs.azure.account.key.2adls.dfs.core.windows.net",
  dbutils.secrets.get(scope="H_scope",key="access-key")
)

# %% [markdown]
# #### Bronze

# %%
# %sql
select * from delta.`abfss://bronze@2adls.dfs.core.windows.net/`

# %% [markdown]
# #### Silver

# %%
# %sql
select * from delta.`abfss://silver@2adls.dfs.core.windows.net/`

# %% [markdown]
# #### Gold

# %%
dim_patient_path = "abfss://gold@2adls.dfs.core.windows.net/dim_patient/"
dim_department_path = "abfss://gold@2adls.dfs.core.windows.net/dim_department/"
fact_tbl_path = "abfss://gold@2adls.dfs.core.windows.net/fact_tbl/"
watermark_path = "abfss://watermark-tbl@2adls.dfs.core.windows.net/"

# %%
# %sql
select * from delta.`abfss://watermark-tbl@2adls.dfs.core.windows.net/`

# %%
# %sql
select * from delta.`abfss://gold@2adls.dfs.core.windows.net/dim_patient/`

# %%
# %sql
select * from delta.`abfss://gold@2adls.dfs.core.windows.net/dim_department/`

# %%
# %sql
select * from delta.`abfss://gold@2adls.dfs.core.windows.net/fact_tbl/`
